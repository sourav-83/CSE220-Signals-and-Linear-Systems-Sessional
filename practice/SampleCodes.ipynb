# %%
print('Welcome to CSE220')
# Out:
# Welcome to CSE220

# %%
age = 51
name = "Alex"
print('My name is '+name)
print('My age is '+str(age))
print(f"My {name} and {age}")
# Out:
# My name is Alex
# My age is 51
# My Alex and 51

# %%
x = 4 
if x==4:
    print('true')
    print('four')
# Out:
# true
# four

# %%
print('Single')
print("Double")
print("""triple""")
# Out:
# Single
# Double
# triple

# %%
name = input('Enter your name')
print(name)

age = int(input())
print(age)

age = age + 4
age
# Out:
# Sojib
# 23
# 27

# %%
a ,b = map(int , input().split(','))
print(a,b)
# Out:
# 5 4

# %%
count = product = 1
count
# Out:
# 1

# %%
s = 'HELLO'
print(type(s))
print(s[0])
# Out:
# <class 'str'>
# H

# %%
i = 13+4j
print(type(i))
# Out:
# <class 'complex'>

# %%
list1 = [1,2,3]
list2 = [1,'two',3.0,[4,5]]
print(type(list2))

list2[1] = 2
print(list2)
# Out:
# <class 'list'>
# [1, 2, 3.0, [4, 5]]

# %%
array = list(map(int , input().split()))
array
# Out:
# [6, 7, 8, 9, 0, 2]

# %%
values_tuple = (1,3,'two')

# %%
list1[::-1]
# Out:
# [3, 2, 1]

# %%
dictionary = {}
dictionary['Jan'] = 1 
dictionary['Feb'] = 2
print(dictionary.get('Mar','Not found'))
# Out:
# Not found

# %%
dictionary.values()
# Out:
# dict_values([1, 2])

# %%
i = 9
j = 4

i = j**3
i/3
# Out:
# 21.333333333333332

# %%
i = 5 
j = 3 
if i==5 or j==3:
    print('ok')
    print('2 ok')
elif i==10:
    print('ok ok')
elif i<0:
    print("oo")
else:
    print(3)
# Out:
# ok
# 2 ok

# %%
list1 = [1,2,3,5,6,6,4]
print(5 not in list1)
# Out:
# False

# %%
i = 0
while i<5:
    print(i)
    i+=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1,5,2):
    print(i)
# Out:
# 1
# 3

# %%
count = 5

# %%
count
# Out:
# 5

# %%
def hello():
    """ This is a multi line comment """
    print('hello') #Hello

def add(a,b,c=10):
    return a+b+c

def modify_list(l):
    l.append(2)

def multiple():
    a = 0
    b = 19
    return a,b

z , y = multiple()
y
# Out:
# 19

# %%
import math as mt 
x = 43.2 
print(mt.sin(x))
print(mt.radians(x))
print(mt.ceil(x))
# Out:
# -0.7049106374142481
# 0.7539822368615504
# 44

# %%
from math import exp 
print(exp(0))
# Out:
# 1.0

# %%
in_file = open('instruction.txt','r')
for x in in_file:
    print(x)
in_file.close()
# Out:
# Welcome to CSE220!!
#
# Hello

# %%
new_file = open('newfile.txt','a')
new_file.write('\n Good luck')
new_file.close()

# %%
class cat:
    def __init__(self,age,name):
        self.age = age 
        self.name = name
    
    def __str__(self):
        return f"{self.name} is {self.age} years old"

    def info(self):
        print(self.name)

cat1 = cat(2,'abc')
print(cat1)
# Out:
# abc is 2 years old
